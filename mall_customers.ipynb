# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import env
import wrangle, prepare, explore

# %%
mall_df = wrangle.wrangle_mall()
mall_df
# Out:
#      customer_id  gender  age  annual_income  spending_score
# 0              1    Male   19             15              39
# 1              2    Male   21             15              81
# 2              3  Female   20             16               6
# 3              4  Female   23             16              77
# 4              5  Female   31             17              40
# ..           ...     ...  ...            ...             ...
# 195          196  Female   35            120              79
# 196          197  Female   45            126              28
# 197          198    Male   32            126              74
# 198          199    Male   32            137              18
# 199          200    Male   30            137              83
#
# [200 rows x 5 columns]

# %%
mall_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     200 non-null    int64
#  1   gender          200 non-null    object
#  2   age             200 non-null    int64
#  3   annual_income   200 non-null    int64
#  4   spending_score  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 9.4+ KB

# %%
mall_df = mall_df[mall_df.columns.drop('customer_id')]
mall_df
# Out:
#      gender  age  annual_income  spending_score
# 0      Male   19             15              39
# 1      Male   21             15              81
# 2    Female   20             16               6
# 3    Female   23             16              77
# 4    Female   31             17              40
# ..      ...  ...            ...             ...
# 195  Female   35            120              79
# 196  Female   45            126              28
# 197    Male   32            126              74
# 198    Male   32            137              18
# 199    Male   30            137              83
#
# [200 rows x 4 columns]

# %%
mall_df['top25'] = mall_df['spending_score'] > 75

# %%
train, validate, test = prepare.train_validate_test_split(mall_df)

# %%
explore.plot_variable_pairs(train, 'top25')

# %%
explore.plot_categorical_and_continuous_vars(train, 'top25', train['age'])

# %%
explore.plot_categorical_and_continuous_vars(train, 'top25', train['annual_income'])

# %%
explore.heat_corr(train)
# Out:
# <AxesSubplot:>
